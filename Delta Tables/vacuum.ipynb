# %%
from delta.tables import *
DeltaTable.create(spark) \
    .tableName('scd2demo1') \
    .addColumn('pk1','INT') \
    .addColumn('pk2','STRING') \
    .addColumn('dim1','INT') \
    .addColumn('dim2','INT') \
    .addColumn('dim3','INT') \
    .addColumn('dim4','INT') \
    .addColumn('active_status', 'STRING') \
    .addColumn('start_date','TIMESTAMP') \
    .addColumn('end_date','TIMESTAMP') \
    .location('/Filestore/tables/scd2demo1') \
    .execute()
# Out:
# Out[1]: <delta.tables.DeltaTable at 0x7fab86fc9ac0>

# %%
# %sql
insert into scd2demo1 values (111,'unit1',200,500,600,700,'N','2014-07-02 06:14:00','2024-08-08 07:14:00');
insert into scd2demo1 values (113,'unit3',205,506,608,709,'N','2014-07-05 06:14:00','2024-08-09 07:14:00');
insert into scd2demo1 values (112,'unit2',204,504,604,704,'Y','2014-07-03 06:14:00','2024-08-09 07:14:00');
insert into scd2demo1 values (114,'unit4',205,504,602,701,'y','2014-07-07 06:14:00','2024-08-09 07:14:00');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
insert into scd2demo1 values (115,'unit5',200,500,600,700,'N','2014-07-02 06:14:00','2024-08-08 07:14:00');
insert into scd2demo1 values (116,'unit6',205,506,608,709,'N','2014-07-05 06:14:00','2024-08-09 07:14:00');
insert into scd2demo1 values (117,'unit7',204,504,604,704,'Y','2014-07-03 06:14:00','2024-08-09 07:14:00');
insert into scd2demo1 values (118,'unit8',205,504,602,701,'y','2014-07-07 06:14:00','2024-08-09 07:14:00');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from scd2demo1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
delete from scd2demo1 where pk1 = 111;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %%
# %sql
update scd2demo1 set dim1 = 100 where pk1=112;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
optimize scd2demo1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/Filestore/tables/scd2demo1</td><td>List(1, 5, List(2727, 2727, 2727.0, 1, 2727), List(2523, 2594, 2538.2, 5, 12691), 0, null, 1, 5, 0, true, 0, 0, 1677172575761, 1677172582966, 8, 1, null)</td></tr></tbody></table></div>

# %%
# %sql
select * from scd2demo1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
describe history scd2demo1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls dbfs:/Filestore/tables/scd2demo1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SET spark.databricks.delta.retentionDurationCheck.enabled = false;
SET spark.databricks.delta.vacuum.logging.enabled = true;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>spark.databricks.delta.vacuum.logging.enabled</td><td>true</td></tr></tbody></table></div>

# %% [markdown]
# #### DRY RUN is used to show the files which are going to be deleted.

# %%
# %sql

VACUUM scd2demo1 RETAIN 0 HOURS DRY RUN
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql

VACUUM scd2demo1

# %% [markdown]
# #### z-order

# %%
# %sql
optimize scd2demo1 zorder pk1
